# %% [markdown]
# #Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Installing & Importing Libraries

# %%
#  Core stack
# !pip install -upgrade numpy==1.24.3 pandas scipy matplotlib seaborn plotly tqdm requests

#  Automated EDA with ydata-profiling and support libraries
# !pip install -U ydata-profiling
# !pip install pydantic PyYAML jinja2 visions htmlmin phik typeguard
# !pip install requests tqdm seaborn multimethod dacite
# !pip install imagehash wordcloud numba

# DateTime
# !pip install datetime

#  Model Explainability
# !pip install shap lime
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -u
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.2 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=6a9393a41091e68ef7e293f79ccb6d83af8baea1d73d0a42ce8294f1e21d728b
# ...

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time

# %%
# Import the necessary modules
import pandas as pd
import math
import random
import matplotlib.pyplot as plt
from scipy import stats
import sys
import os
import numpy as np
import seaborn as sns

# %%
#  Basic Utilities
import os
import sys
import math
import random
import warnings
from google.colab import drive
warnings.filterwarnings("ignore")

#  Data Handling

import pandas as pd
import numpy as np

# Time Series Utilities
from pandas.tseries.offsets import DateOffset
import datetime


#  EDA Automation

from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# Library
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns
sns.set_style("whitegrid")
from matplotlib import pyplot

# %% [markdown]
# #Load Dataset

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/MRP/Current/Deliverables/Methodology_&_Experiments/Report/Coding/Data_files/Data_Co.csv', encoding='latin-1')

# %% [markdown]
# **Data Preparation**

# %%
display(df)

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()
# Out:
# date                             0
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
#                                 ..
# shipping_hour                    0
# shipping_week                    0
# shipping_month                   0
# shipping_dayofweek               0
# shipping_weekend                 0
# Length: 62, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (180508, 62)

# %%
df.columns

# %%
df.dtypes

# %%
df.head()
# Out:
#                   date      Type  Days for shipping (real)  \
# 0  2018-01-31 22:56:00     DEBIT                         3
# 1  2018-01-13 12:27:00  TRANSFER                         5
# 2  2018-01-13 12:06:00      CASH                         4
# 3  2018-01-13 11:45:00     DEBIT                         3
# 4  2018-01-13 11:24:00   PAYMENT                         2
#
#    Days for shipment (scheduled)  Benefit per order  Sales per customer  \
# 0                              4          91.250000          314.640015
# 1                              4        -249.089996          311.359985
# 2                              4        -247.779999          309.720001
# 3                              4          22.860001          304.809998
# 4                              4         134.210007          298.250000
#
#     Delivery Status  Late_delivery_risk  Category Id   Category Name  ...  \
# 0  Advance shipping                   0           73  Sporting Goods  ...
# ...

# %%
df.tail()
# Out:
#                        date      Type  Days for shipping (real)  \
# 180503  2016-01-16 03:40:00      CASH                         4
# 180504  2016-01-16 01:34:00     DEBIT                         3
# 180505  2016-01-15 21:00:00  TRANSFER                         5
# 180506  2016-01-15 20:18:00   PAYMENT                         3
# 180507  2016-01-15 18:54:00   PAYMENT                         4
#
#         Days for shipment (scheduled)  Benefit per order  Sales per customer  \
# 180503                              4          40.000000          399.980011
# 180504                              2        -613.770019          395.980011
# 180505                              4         141.110001          391.980011
# 180506                              4         186.229996          387.980011
# 180507                              4         168.949997          383.980011
#
#          Delivery Status  Late_delivery_risk  Category Id Category Name  ...  \
# ...

# %%
df['Sales'].unique()
# Out:
# array([ 327.75      ,  119.9800034 ,   79.98000336,  100.        ,
#          89.98000336,  109.9400024 ,  299.9700012 ,  119.9700012 ,
#          65.97000122,   95.97000122,  179.9700012 ,  150.        ,
#         250.        ,  199.9499969 ,  239.9499969 ,  159.9499969 ,
#         449.9500122 ,  149.9499969 ,  299.9500122 ,  499.9500122 ,
#          99.98999786,  129.9900055 ,   59.99000168,  299.980011  ,
#         252.8800049 ,  452.0400085 , 1500.        ,  999.9899902 ,
#          79.98999786,   44.99000168,  134.9700012 ,   75.        ,
#          74.97000122,   47.97000122,  239.9600067 ,  200.        ,
#         159.9600067 ,   99.95999908,  399.9599915 ,  120.        ,
#         215.8200073 ,  461.480011  ,  210.8500061 ,  124.9499969 ,
#          79.94999695,  224.9499969 ,  174.9499969 ,  139.9499969 ,
#         140.        ,   50.        ,   63.97999954,   49.97999954,
#          39.97999954,   95.98000336,  127.9599991 ,  207.9600067 ,
# ...

# %%
#calculate the minimum
# Select only numeric columns to avoid the TypeError
numeric_data = df.select_dtypes(include=np.number)
print(numeric_data.min())

# %%
df['Sales'].describe()

# %%
df['Sales'].info()

# %% [markdown]
# **Expolatory Data Analysis**

# %%
# Panda Profiling report
# !pip install ydata_profiling
from ydata_profiling import ProfileReport
ydata_profiling = ProfileReport(df)

# Saving the report to an HTML file
ydata_profiling.to_file('/content/drive/MyDrive/MRP/Current/Deliverables/Methodology_&_Experiments/Report/Coding/Data_files/DataCo_report.html')

# %%
# The following command generates the pandaprofiling report
ydata_profiling
